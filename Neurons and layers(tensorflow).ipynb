# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from lab_coffee_utils import plt_linear
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\style\core.py in use(style)
#     126             try:
# --> 127                 rc = rc_params_from_file(style, use_default_template=False)
#     128                 _apply_style(rc)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     851     """
# --> 852     config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     853
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     777     rc_temp = {}
# --> 778     with _open_file_or_url(fname) as fd:
#     779         try:
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in _open_file_or_url(fname)
#     754             encoding = "utf-8"
# --> 755         with open(fname, encoding=encoding) as f:
#     756             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: './deeplearning.mplstyle'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4932\970110788.py in <module>
#       4 import tensorflow as tf
#       5 from tensorflow.keras.layers import Dense, Input
# ----> 6 from lab_coffee_utils import plt_linear
#
# ~\Machine learning\lab_coffee_utils.py in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.style.use('./deeplearning.mplstyle')
#       4 import tensorflow as tf
#       5 from tensorflow.keras.activations import sigmoid
#
# ~\anaconda3\lib\site-packages\matplotlib\style\core.py in use(style)
#     128                 _apply_style(rc)
#     129             except IOError as err:
# --> 130                 raise IOError(
#     131                     "{!r} not found in the style library and input is not a "
#     132                     "valid URL or path; see `style.available` for list of "
#
# OSError: './deeplearning.mplstyle' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
X_train=np.array([[1.0],[2.0]])
Y_train=np.array([[300.0],[500.0]])

fig,ax=plt.subplots()
ax.scatter(X_train,Y_train,marker='x',c='r',label='Data')
ax.legend(fontsize='xx-large')
ax.set_ylabel('Price (in 1000s of dollars)',fontsize='xx-large')
ax.set_xlabel('Size (1000 sqft)', fontsize='xx-large')
plt.show()

# %%
linear_layer=tf.keras.layers.Dense(units=1,activation='linear',)

# %%
linear_layer.get_weights()
# Out:
# []

# %%
a1=linear_layer(X_train[0].reshape(1,1))
print(a1)
# Out:
# tf.Tensor([[-0.02618623]], shape=(1, 1), dtype=float32)

# %%
w,b=linear_layer.get_weights()
print(f"w={w},b={b}")
# Out:
# w=[[-0.02618623]],b=[0.]

# %%
set_w=np.array([[200]])
set_b=np.array([100])
linear_layer.set_weights([set_w,set_b])
print(linear_layer.get_weights())
# Out:
# [array([[200.]], dtype=float32), array([100.], dtype=float32)]

# %%
a1=linear_layer(X_train[0].reshape(1,1))
print(a1)
alin=np.dot(set_w,X_train[0].reshape(1,1))+set_b
print(alin)
# Out:
# tf.Tensor([[300.]], shape=(1, 1), dtype=float32)
# [[300.]]

# %%
prediction_tf=linear_layer(X_train)
prediction_np=np.dot(X_train,set_w)+set_b

# %%
plt_linear(X_train,Y_train,prediction_tf,prediction_np)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16288\4116390568.py in <module>
# ----> 1 plt_linear(X_train,Y_train,prediction_tf,prediction_np)
#
# NameError: name 'plt_linear' is not defined

# %%
x=np.array([200,17])
W=np.array([[1,-3,5],
          [2,4,-6]])
b=np.array([-1,1,2])
print(x)
print(W)
print(b)
# Out:
# [200  17]
# [[ 1 -3  5]
#  [ 2  4 -6]]
# [-1  1  2]

# %%
def dense(a_in,W,b):
    units=W.shape[1]
    a_o=np.zeros(units)
    for i in range(units):
        w=W[:,j]
        z=np.dot(w,a_in)+b[i]
        a_o[i]=g(z)
    return a_o

# %% [markdown]
# # for loop vs vectorization
# For vectorization

# %%
x=np.array([[200,17]])  #changing 1_d array to 2_d array
b=np.array([-1,1,2])

# %%
def dense(A_in,W,B):
    Z=np.matmul(A_in,W)+B
    A_out=g(Z)
    return A_out
