# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       2 import librosa.display
#       4 plt.figure().set_figwidth(12)
# ----> 5 librosa.display.waveshow(array, sr=sampling_rate)
#
# File ~/tensorflow-test/env/lib/python3.10/site-packages/librosa/display.py:2042, in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2032 axis = rename_kw(
#    2033     old_name="x_axis",
#    2034     old_value=x_axis,
#    (...)
#    2038     version_removed="1.0",
#    2039 )
#    2041 if "color" not in kwargs:
# -> 2042     kwargs.setdefault("color", next(axes._get_lines.prop_cycler)["color"])
#    2044 # Reduce by envelope calculation
#    2045 # this choice of hop ensures that the envelope has at most max_points values
#    2046 hop_length = max(1, y.shape[-1] // max_points)
#
# ...
